# %% [markdown]
# # Generate Publication Figures
#
# Set the result folder and optional suffix in the config cell, then run all cells. To generate a variant, change only `RESULTS_PATH` and `OUTPUT_SUFFIX`.

# %%
from pathlib import Path
import sys

REPO_ROOT = Path('..').resolve()
sys.path.insert(0, str(REPO_ROOT / 'scripts'))

from figure_helpers import run_all_figures

# %%
# Edit only these values for figure variants.
RESULTS_PATH = REPO_ROOT / 'results_area'
OUTPUT_DIR = REPO_ROOT / 'outputs'
OUTPUT_SUFFIX = ''  # examples: 'area_scaled_gen4', 'vsplit_scaled_gen4'

# Static/reference figures are generated automatically for the unsuffixed run.
INCLUDE_STATIC = None

# %%
run_all_figures(
    results_path=RESULTS_PATH,
    output_dir=OUTPUT_DIR,
    suffix=OUTPUT_SUFFIX,
    include_static=INCLUDE_STATIC,
)
