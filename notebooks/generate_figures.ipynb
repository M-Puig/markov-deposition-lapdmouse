# %% [markdown]
# # Generate Publication Figures
#
# Set `RESULTS_PATH` to the folder produced by
# `scripts/compare_impaction_models.py`, then run all cells. Figures and
# `results_summary*` files are written to `OUTPUT_DIR`.

# %%
from pathlib import Path
import sys

REPO_ROOT = Path('..').resolve()
sys.path.insert(0, str(REPO_ROOT / 'scripts'))

from figure_helpers import run_all_figures

# %%
# Point at the folder produced by scripts/compare_impaction_models.py.
RESULTS_PATH = REPO_ROOT / 'results_main'
OUTPUT_DIR = REPO_ROOT / 'outputs'
OUTPUT_SUFFIX = ''

# Ground-truth / reference figures are generated automatically for the main run.
INCLUDE_STATIC = None

# %%
run_all_figures(
    results_path=RESULTS_PATH,
    output_dir=OUTPUT_DIR,
    suffix=OUTPUT_SUFFIX,
    include_static=INCLUDE_STATIC,
)
